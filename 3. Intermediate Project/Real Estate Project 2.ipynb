# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### Put all together

# %%
# create empty dataframe
real_estate = pd.DataFrame(columns=['Street','Regions','Beds','Baths','Price'])

# scrape 3 pages 
# sequence of number (1 up 3,4 is not included)
for i in range(1,4):
    # website request
    website = "https://www.trulia.com/CA/San_Francisco/"+ str(i) + "_p/"
    response = requests.get(website)

    # create soup object
    soup = BeautifulSoup(response.content,'html.parser')

    # result items
    results = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})

    #update results
    results_update=[]
    for r in results:
        if r.has_attr('data-testid'):
            results_update.append(r)

            
    # Lists
    streets = [result.find('div',{'data-testid':'property-street'}).get('title') for result in results_update]
    regions = [result.find('div',{'data-testid':'property-region'}).get('title') for result in results_update]
    bedrooms = [result.find('div',{'data-testid':'property-beds'}).get_text() for result in results_update]
    bathrooms = [result.find('div',{'data-testid':'property-baths'}).get_text() for result in results_update]
    prices = [result.find('div',{'data-testid':'property-price'}).get('title') for result in results_update]
    
    for k in range(len(streets)):
        real_estate = real_estate.append({'Street':streets[k],
                                          'Regions':regions[k],
                                          'Beds':bedrooms[k],
                                          'Baths':bathrooms[k],
                                          'Price':prices[k],
                                         },ignore_index=True)

# %% [markdown]
# ### Information about Dataframe

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Street   120 non-null    object
#  1   Regions  120 non-null    object
#  2   Beds     120 non-null    object
#  3   Baths    120 non-null    object
#  4   Price    120 non-null    object
# dtypes: object(5)
# memory usage: 4.8+ KB

# %%
real_estate.head()
# Out:
#               Street                            Regions Beds Baths  \
# 0      2018 42nd Ave    Outer Sunset, San Francisco, CA  2bd   1ba
# 1       4366 25th St      Noe Valley, San Francisco, CA  3bd   2ba
# 2  224 Sea Cliff Ave        Seacliff, San Francisco, CA  6bd   7ba
# 3       45 Capra Way          Marina, San Francisco, CA  4bd   6ba
# 4    122 Chicago Way  Crocker Amazon, San Francisco, CA  4bd   3ba
#
#          Price
# 0     $899,000
# 1   $1,795,000
# 2  $15,375,000
# 3  $10,300,000
# 4   $1,095,000

# %%
real_estate.tail()
# Out:
#                Street                             Regions Beds Baths  \
# 115      1506 25th St     Potrero Hill, San Francisco, CA  4bd   3ba
# 116     262 Downey St  Ashbury Heights, San Francisco, CA  2bd   2ba
# 117     148 Corwin St    Eureka Valley, San Francisco, CA  2bd   3ba
# 118  898 Francisco St     Russian Hill, San Francisco, CA  6bd   7ba
# 119      1828 Page St           Haight, San Francisco, CA  2bd   2ba
#
#           Price
# 115  $1,995,000
# 116  $1,199,000
# 117  $1,699,000
# 118  $9,950,000
# 119  $1,395,000

# %% [markdown]
# ### Data Cleaning

# %%
real_estate['Beds'] = real_estate['Beds'].apply(lambda x: x.strip('bd'))
real_estate['Baths'] = real_estate['Baths'].apply(lambda x: x.strip('ba'))

# %% [markdown]
# #### Update DataFrame

# %%
real_estate
# Out:
#                 Street                             Regions Beds Baths  \
# 0        2018 42nd Ave     Outer Sunset, San Francisco, CA    2     1
# 1         4366 25th St       Noe Valley, San Francisco, CA    3     2
# 2    224 Sea Cliff Ave         Seacliff, San Francisco, CA    6     7
# 3         45 Capra Way           Marina, San Francisco, CA    4     6
# 4      122 Chicago Way   Crocker Amazon, San Francisco, CA    4     3
# ..                 ...                                 ...  ...   ...
# 115       1506 25th St     Potrero Hill, San Francisco, CA    4     3
# 116      262 Downey St  Ashbury Heights, San Francisco, CA    2     2
# 117      148 Corwin St    Eureka Valley, San Francisco, CA    2     3
# 118   898 Francisco St     Russian Hill, San Francisco, CA    6     7
# 119       1828 Page St           Haight, San Francisco, CA    2     2
#
#            Price
# 0       $899,000
# 1     $1,795,000
# 2    $15,375,000
# 3    $10,300,000
# 4     $1,095,000
# ..           ...
# 115   $1,995,000
# 116   $1,199,000
# 117   $1,699,000
# 118   $9,950,000
# 119   $1,395,000
#
# [120 rows x 5 columns]

# %% [markdown]
# ### Save in Excel

# %%
real_estate.to_excel('realestate_multiple_pages.xlsx', index=False)
