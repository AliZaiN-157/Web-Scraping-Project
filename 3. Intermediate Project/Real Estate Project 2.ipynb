# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### Put all together

# %%
# create empty dataframe
real_estate = pd.DataFrame(columns=['Street','Regions','Beds','Baths','Price'])

# scrape 3 pages 
# sequence of number (1 up 3,4 is not included)
for i in range(1,4):
    # website request
    website = "https://www.trulia.com/NY/New_York/"+ str(i) + "_p/"
    response = requests.get(website)

    # create soup object
    soup = BeautifulSoup(response.content,'html.parser')

    # result items
    results = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})

    #update results
    results_update=[]
    for r in results:
        if r.has_attr('data-testid'):
            results_update.append(r)

    # Lists
    streets = [result.find('div',{'data-testid':'property-street'}).get('title') for result in results_update]
    regions = [result.find('div',{'data-testid':'property-region'}).get('title') for result in results_update]
    bedrooms = [result.find('div',{'data-testid':'property-beds'}).get_text() for result in results_update]
    bathrooms = [result.find('div',{'data-testid':'property-baths'}).get_text() for result in results_update]
    prices = [result.find('div',{'data-testid':'property-price'}).get('title') for result in results_update]
    
    for k in range(len(streets)):
        real_estate = real_estate.append({'Street':streets[k],
                                          'Regions':regions[k],
                                          'Beds':bedrooms[k],
                                          'Baths':bathrooms[k],
                                          'Price':prices[k],
                                         },ignore_index=True)

# %%
real_estate
# Out:
#                      Street                          Regions Beds Baths  \
# 0   432 Park Ave #PENTHOUSE            Midtown, New York, NY  6bd   9ba
# 1        303 E 57th St #32B       Sutton Place, New York, NY  2bd   3ba
# 2    27 Prospect Park W #1A         Park Slope, Brooklyn, NY  2bd   2ba
# 3         303 E 57th St #6D       Sutton Place, New York, NY  2bd   2ba
# 4              35 Poland Pl  Emerson Hill, Staten Island, NY  3bd   3ba
# ..                      ...                              ...  ...   ...
# 85       2505 Tenbroeck Ave        Pelham Gardens, Bronx, NY  3bd   3ba
# 86            223 E 28th St           Flatbush, Brooklyn, NY  3bd   2ba
# 87           89-23 202nd St               Hollis, Hollis, NY  4bd   2ba
# 88             37 Groton St   Eltingville, Staten Island, NY  4bd   4ba
# 89        21-57 33rd St #4B             Astoria, Astoria, NY  2bd   1ba
#
#            Price
# 0   $169,000,000
# 1       $379,000
# 2       $589,000
# 3       $375,000
# 4       $699,000
# ..           ...
# 85      $715,000
# 86      $599,000
# 87      $649,000
# 88      $849,999
# 89      $279,000
#
# [90 rows x 5 columns]

# %% [markdown]
# ### Information about Dataframe

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Street   90 non-null     object
#  1   Regions  90 non-null     object
#  2   Beds     90 non-null     object
#  3   Baths    90 non-null     object
#  4   Price    90 non-null     object
# dtypes: object(5)
# memory usage: 3.6+ KB

# %%
real_estate.head()
# Out:
#                     Street                          Regions Beds Baths  \
# 0  432 Park Ave #PENTHOUSE            Midtown, New York, NY  6bd   9ba
# 1       303 E 57th St #32B       Sutton Place, New York, NY  2bd   3ba
# 2   27 Prospect Park W #1A         Park Slope, Brooklyn, NY  2bd   2ba
# 3        303 E 57th St #6D       Sutton Place, New York, NY  2bd   2ba
# 4             35 Poland Pl  Emerson Hill, Staten Island, NY  3bd   3ba
#
#           Price
# 0  $169,000,000
# 1      $379,000
# 2      $589,000
# 3      $375,000
# 4      $699,000

# %%
real_estate.tail()
# Out:
#                 Street                         Regions Beds Baths     Price
# 85  2505 Tenbroeck Ave       Pelham Gardens, Bronx, NY  3bd   3ba  $715,000
# 86       223 E 28th St          Flatbush, Brooklyn, NY  3bd   2ba  $599,000
# 87      89-23 202nd St              Hollis, Hollis, NY  4bd   2ba  $649,000
# 88        37 Groton St  Eltingville, Staten Island, NY  4bd   4ba  $849,999
# 89   21-57 33rd St #4B            Astoria, Astoria, NY  2bd   1ba  $279,000

# %% [markdown]
# ### Data Cleaning

# %%
real_estate['Beds'] = real_estate['Beds'].apply(lambda x: x.strip('bd'))
real_estate['Baths'] = real_estate['Baths'].apply(lambda x: x.strip('ba'))

# %% [markdown]
# #### Update DataFrame

# %%
real_estate
# Out:
#                      Street                          Regions Beds Baths  \
# 0   432 Park Ave #PENTHOUSE            Midtown, New York, NY    6     9
# 1        303 E 57th St #32B       Sutton Place, New York, NY    2     3
# 2    27 Prospect Park W #1A         Park Slope, Brooklyn, NY    2     2
# 3         303 E 57th St #6D       Sutton Place, New York, NY    2     2
# 4              35 Poland Pl  Emerson Hill, Staten Island, NY    3     3
# ..                      ...                              ...  ...   ...
# 85       2505 Tenbroeck Ave        Pelham Gardens, Bronx, NY    3     3
# 86            223 E 28th St           Flatbush, Brooklyn, NY    3     2
# 87           89-23 202nd St               Hollis, Hollis, NY    4     2
# 88             37 Groton St   Eltingville, Staten Island, NY    4     4
# 89        21-57 33rd St #4B             Astoria, Astoria, NY    2     1
#
#            Price
# 0   $169,000,000
# 1       $379,000
# 2       $589,000
# 3       $375,000
# 4       $699,000
# ..           ...
# 85      $715,000
# 86      $599,000
# 87      $649,000
# 88      $849,999
# 89      $279,000
#
# [90 rows x 5 columns]

# %% [markdown]
# ### Save in Excel

# %%
real_estate.to_excel('realestate_multiple_pages.xlsx', index=False)
