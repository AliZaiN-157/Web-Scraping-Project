# %% [markdown]
# ### Step 1 - Import Packages

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Step 2 - Requests & CURL

# %%
headers = {
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
    'Referer': 'https://www.ebooks.com/en-pk/subjects/computers/',
    'sec-ch-ua-mobile': '?1',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Mobile Safari/537.36',
    'Content-Type': 'application/json',
}

params = (
    ('subjectId', '13'),
    ('pageNumber', '1'),
    ('countryCode', 'PK'),
)

response = requests.get('https://www.ebooks.com/api/search/subject/', headers=headers, params=params)

# %% [markdown]
# ### Step 3 - Check Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Step 4 - Create JSON Object

# %%
response.json()
# Out:
# {'pages': [{'number': '1',
#    'is_selected': True,
#    'show_mobile': True,
#    'show_tablet': True,
#    'search_url': 'https://www.ebooks.com/en-pk/subjects/computers/'},
#   {'number': '2',
#    'is_selected': False,
#    'show_mobile': True,
#    'show_tablet': True,
#    'search_url': 'https://www.ebooks.com/en-pk/subjects/computers/?pageNumber=2'},
#   {'number': '3',
#    'is_selected': False,
#    'show_mobile': True,
#    'show_tablet': True,
#    'search_url': 'https://www.ebooks.com/en-pk/subjects/computers/?pageNumber=3'},
#   {'number': '4',
#    'is_selected': False,
#    'show_mobile': True,
#    'show_tablet': True,
#    'search_url': 'https://www.ebooks.com/en-pk/subjects/computers/?pageNumber=4'},
#   {'number': '5',
#    'is_selected': False,
#    'show_mobile': True,
#    'show_tablet': True,
#    'search_url': 'https://www.ebooks.com/en-pk/subjects/computers/?pageNumber=5'},
#   {'number': '6',
#    'is_selected': False,
#    'show_mobile': False,
# ...

# %% [markdown]
# ### Step 5 - Output Keys

# %%
response.json().keys()
# Out:
# dict_keys(['pages', 'previous_page', 'next_page', 'books', 'result_page_range'])

# %% [markdown]
# ### Step 6 - Find your Data

# %%
# title
# subtitle
# author
# publisher
# publication date
# price

# %%
book_results= response.json()['books']

# %%
len(book_results)
# Out:
# 10

# %% [markdown]
# ### Step 7 - Put everything together
# ####  Loop through results and append data inside a list

# %%
book_results[0]
# Out:
# {'id': 209755044,
#  'book_url': '/en-pk/book/209755044/dark-data/david-j-hand/',
#  'image_url': 'https://image.ebooks.com/previews/209/209755/209755044/209755044-sml-1.jpg',
#  'image_alt_tag': 'Dark Data: Why What You Don&#x2019;t Know Matters',
#  'title': 'Dark Data',
#  'edition': '',
#  'subtitle': 'Why What You Don’t Know Matters',
#  'authors': [{'author_name': 'David J. Hand',
#    'author_url': '/en-pk/author/david-j.-hand/165723/'}],
#  'num_authors': 1,
#  'series': ' Series',
#  'series_number': '',
#  'has_series': False,
#  'series_url': '',
#  'publisher': 'Princeton University Press',
#  'publication_year': '2020',
#  'price': 'US$27.25',
# ...

# %%
# title
book_results[0]['title']
# subtitle 
book_results[0]['subtitle']
# author
book_results[0]['authors'][0]['author_name']
# publisher
book_results[0]['publisher']
# publication date
book_results[0]['publication_year']
# price 
book_results[0]['price']
# Out:
# 'US$27.25'

# %%
title = []
subtitle = []
author = []
publisher = []
publication_year = []
price = []

for results in book_results:
    title.append(results['title'])
    subtitle.append(results['subtitle'])
    author.append(results['authors'][0]['author_name'])
    publisher.append(results['publisher'])
    publication_year.append(results['publication_year'])
    price.append(results['price'])

# %% [markdown]
# ### Step 8 - Create Dataframe

# %%
books_df = pd.DataFrame({'Title':title, 
                         'Subtitle':subtitle, 
                         'Author':author, 
                         'Publisher':publisher, 
                         'Publication Year':publication_year, 
                         'Price':price
                        })

# %%
books_df
# Out:
#                                                Title  \
# 0                                          Dark Data
# 1                                       HTML and CSS
# 2                Effective SEO and Content Marketing
# 3                                  Business Analysis
# 4                      CompTIA Security+ Study Guide
# 5  (ISC)2 CISSP Certified Information Systems Sec...
# 6  The Official (ISC)2 Guide to the CISSP CBK Ref...
# 7                CompTIA Security+ SY0-601 Exam Cram
# 8                                Software in 30 Days
# 9      AWS Certified Solutions Architect Study Guide
#
#                                             Subtitle                Author  \
# 0                    Why What You Don’t Know Matters         David J. Hand
# 1                          Design and Build Websites           Jon Duckett
# 2  The Ultimate Guide for Maximizing Free Web Tra...  Nicholas Papagiannis
# 3                                                               Debra Paul
# ...

# %% [markdown]
# ### Step 9 - Dataframe to Excel

# %%
books_df.to_excel('books.xlsx', index=False)
